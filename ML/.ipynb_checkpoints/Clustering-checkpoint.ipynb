# %%
import numpy as np
import pandas as pd 
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

# %%
aStocksTrain = pd.read_csv('acolstocksTrain.csv')
mStocksTest = pd.read_csv('mcolstocksTest.csv')

# %%
aStocksTrain.head(5)
# Out:
#          Date         A        AA  AAAP  AAC      AADR       AAL      AAMC  \
# 0  2014-01-01       NaN       NaN   NaN  NaN       NaN       NaN       NaN
# 1  2014-01-02       NaN       NaN   NaN  NaN       NaN       NaN       NaN
# 2  2014-01-03  1.218414  0.123848   NaN  NaN  0.184038  4.458617  0.544710
# 3  2014-01-06  0.063120  0.260523   NaN  NaN -0.565814  2.394917  0.360864
# 4  2014-01-07  0.487010 -0.605852   NaN  NaN  0.400905 -1.536030  1.341908
#
#        AAME       AAN    ...          AYI       AYR       AYT  AYX       AZN  \
# 0       NaN       NaN    ...          NaN       NaN       NaN  NaN       NaN
# 1       NaN       NaN    ...          NaN       NaN       NaN  NaN       NaN
# 2  2.259984  0.039267    ...     0.191663 -0.619026 -0.006476  NaN  0.602720
# 3 -1.046592  0.309195    ...    -1.294586  0.019111  0.033307  NaN  0.352939
# 4  0.231343 -2.097688    ...     1.912880 -1.275911 -0.102969  NaN -1.362524
#
#         AZO      AZPN  AZRE  AZRX       AZZ
# ...

# %%
# Removing observations with NAN values
aStocksTrain.dropna(axis=0,how='all')
# Out:
#            Date         A        AA      AAAP        AAC      AADR       AAL  \
# 0    2014-01-01       NaN       NaN       NaN        NaN       NaN       NaN
# 1    2014-01-02       NaN       NaN       NaN        NaN       NaN       NaN
# 2    2014-01-03  1.218414  0.123848       NaN        NaN  0.184038  4.458617
# 3    2014-01-06  0.063120  0.260523       NaN        NaN -0.565814  2.394917
# 4    2014-01-07  0.487010 -0.605852       NaN        NaN  0.400905 -1.536030
# 5    2014-01-08  1.579876  2.842494       NaN        NaN  0.368383  2.545666
# 6    2014-01-09 -0.050620 -0.982805       NaN        NaN -0.310531  6.147676
# 7    2014-01-10  0.371322 -5.400032       NaN        NaN  0.056085 -0.835330
# 8    2014-01-13  1.682192  1.753100       NaN        NaN -0.552526 -0.551583
# 9    2014-01-14  0.116392  0.907342       NaN        NaN  0.635740 -0.957389
# 10   2014-01-15  0.159028  1.550831       NaN        NaN -0.326929 -0.851287
# ...

# %% [markdown]
# ### KNN

# %%
# Instatiating the object
knn = KNeighborsClassifier(n_neighbors=2)

# %%
aStocksTrain.iloc[4:5,1:]
# Out:
#          A        AA  AAAP  AAC      AADR      AAL      AAMC      AAME  \
# 4  0.48701 -0.605852   NaN  NaN  0.400905 -1.53603  1.341908  0.231343
#
#         AAN      AAOI    ...         AYI       AYR       AYT  AYX       AZN  \
# 4 -2.097688  1.400914    ...     1.91288 -1.275911 -0.102969  NaN -1.362524
#
#         AZO      AZPN  AZRE  AZRX       AZZ
# 4  0.333081  0.299191   NaN   NaN -0.502222
#
# [1 rows x 564 columns]

# %%
# TODO KNN, implement your own. Using the built library the implementation will be too simple

# %% [markdown]
# #### Getting a different dataset

# %%
# Creating header
colnames = ['Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoid',\
            'Nonflavanoid phenols','Proanthocyanis','Color Intensity', 'Hue','OD280/OD315','Proline']

# %%
# Reading csv and concatenating the header
wineData = pd.read_csv('wine.data.csv', names=colnames, index_col=False)

# %%
# Cross-validation 
trainData, testData = train_test_split(wineData, test_size = 0.2)

# %% [markdown]
# ### K-Means
