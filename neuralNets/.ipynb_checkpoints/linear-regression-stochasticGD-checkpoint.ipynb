# %% [markdown]
# ## Linear Regression
#
# In this section we will implement a linear regression model trainable with SGD using numpy. Here are the objectives:
#
# 1. Implement a simple forward model: $y = W x + b$
#
# 1. build a `predict` function which returns the predicted regression value given an input $x$
#
# 1. build an `accuracy` function for a batch of inputs $X$ and the corresponding expected outputs $y_{true}$ (for regression we typically use Mean Squared Error (MSE) as metric)
#
# 1. build a `grad` function which computes the gradients for an $x$ and its corresponding expected output $y_{true}$ ; check that the gradients are well defined
#
# 1. build a `train` function which uses the `grad` function output to update $W$ and $b$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams["font.size"] = 14

import numpy as np

# %%
# our toy data for this task
x = np.random.uniform(0, 10, size=20)
temp = 1.3*x + 15 + np.random.normal(0, 1, size=20)

# %%
plt.plot(x, temp, 'o')
plt.xlabel("Minutes of sunshine in the last 10minutes")
plt.ylabel("Temperature [C]");

# %%
class LinearRegression():
    def __init__(self):
        self.W = np.random.uniform(high=0.5, low=-0.5)
        self.b = np.random.uniform(high=0.5, low=-0.5)
    
    def predict(self, X):
        y_pred = self.W*X + self.b
        return y_pred
    
    def grad_loss(self, x, y_true):
        # TODO?: compute gradient with respect to W and b for one sample x
        # and the true value y_true
        grad_b = 0
        grad_W = 0

        #calculating the change for each point
        grad_b += - 2 * (y_true - ((self.W*x) + self.b))
        grad_W += - 2 * x * (y_true - ((self.W * x) + self.b))
        
        grads = {"W": grad_W, "b": grad_b}
        return grads
    
    def train(self, x, y, learning_rate):
        # TODO: compute one step of the gradient descent update, update W and b
        grads = self.grad_loss(x, y)
        
        self.W = self.W - (learning_rate * grads['W'])
        self.b = self.b - (learning_rate * grads['b'])
        
    def loss(self, x, y):
        y_pred = self.predict(x)
        loss = (y - y_pred)**2
        
        return loss

    def accuracy(self, X, y):
        acc = np.empty(len(X))
        
        for value, result in zip(X, y):
            np.append(acc, self.loss(value, result))          
            
        ols = np.sum(acc)/len(X)

        return ols

# %% [markdown]
# Questions:
#
# * how do you know that you trained for enough epochs?
# * visualise how the loss changes over the epochs
# * are more epochs always better? How could you show this?
# * change the setup to use stochastic gradient descent
# * (bonus) visualise the values of W and b over the epochs
# * (bonus) can you see a difference for the paths of W and b between SGD and normal GD?

# %%
lr = LinearRegression()
print('initial value of W: %.4f and b: %.4f' % (lr.W, lr.b))
# Out:
# initial value of W: 0.1161 and b: -0.1944

# %%
# Train for one epoch
learning_rate = 0.001
for epoch in range(1,10):
    for i, (x_, y_) in enumerate(zip(x, temp)):
        lr.train(x_, y_, learning_rate)
        train_acc = lr.accuracy(x, temp)
        print("Update: train accuracy: %.4f"% (train_acc), end=' ')
        print('value of W: %.4f and b: %.4f' % (lr.W, lr.b))
# Out:
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7213 and b: 2.1201
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7228 and b: 2.1203
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7401 and b: 2.1421
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6848 and b: 2.1340
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7129 and b: 2.1454
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6917 and b: 2.1412
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7197 and b: 2.1605
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6898 and b: 2.1562
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7258 and b: 2.1657
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7345 and b: 2.1674
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7669 and b: 2.1814
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.8054 and b: 2.1933
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7183 and b: 2.1804
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7490 and b: 2.1980
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7781 and b: 2.2052
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.8064 and b: 2.2161
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.8076 and b: 2.2164
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7300 and b: 2.2052
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7433 and b: 2.2080
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7374 and b: 2.2068
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7055 and b: 2.2016
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7071 and b: 2.2019
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7243 and b: 2.2235
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6694 and b: 2.2155
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6972 and b: 2.2267
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6760 and b: 2.2225
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7038 and b: 2.2418
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6743 and b: 2.2375
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7101 and b: 2.2469
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7188 and b: 2.2487
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7510 and b: 2.2626
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7893 and b: 2.2744
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7026 and b: 2.2616
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7331 and b: 2.2790
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7620 and b: 2.2862
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7902 and b: 2.2971
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7913 and b: 2.2973
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7142 and b: 2.2862
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7274 and b: 2.2890
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7215 and b: 2.2877
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6898 and b: 2.2826
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6915 and b: 2.2829
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7085 and b: 2.3044
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6540 and b: 2.2964
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6816 and b: 2.3076
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6604 and b: 2.3034
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6880 and b: 2.3225
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6588 and b: 2.3183
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6946 and b: 2.3277
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7031 and b: 2.3294
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7352 and b: 2.3432
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7733 and b: 2.3550
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6869 and b: 2.3422
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7173 and b: 2.3596
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7461 and b: 2.3667
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7740 and b: 2.3775
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7752 and b: 2.3777
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6985 and b: 2.3667
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7117 and b: 2.3695
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7057 and b: 2.3682
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6742 and b: 2.3631
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6759 and b: 2.3634
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6929 and b: 2.3848
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6387 and b: 2.3768
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6661 and b: 2.3880
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6448 and b: 2.3837
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6723 and b: 2.4028
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6435 and b: 2.3986
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6791 and b: 2.4079
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6876 and b: 2.4096
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7195 and b: 2.4234
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7574 and b: 2.4351
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6714 and b: 2.4224
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7015 and b: 2.4396
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7302 and b: 2.4467
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7579 and b: 2.4574
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7592 and b: 2.4577
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6829 and b: 2.4467
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6960 and b: 2.4495
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6900 and b: 2.4482
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6587 and b: 2.4431
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6605 and b: 2.4434
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6773 and b: 2.4647
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6235 and b: 2.4568
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6507 and b: 2.4678
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6294 and b: 2.4636
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6567 and b: 2.4825
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6283 and b: 2.4783
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6637 and b: 2.4877
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6722 and b: 2.4894
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7038 and b: 2.5030
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7416 and b: 2.5147
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6560 and b: 2.5020
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6859 and b: 2.5191
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7144 and b: 2.5262
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7420 and b: 2.5368
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7432 and b: 2.5371
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6674 and b: 2.5262
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6805 and b: 2.5289
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6744 and b: 2.5277
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6433 and b: 2.5226
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6451 and b: 2.5230
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6619 and b: 2.5440
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6084 and b: 2.5362
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6354 and b: 2.5471
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6141 and b: 2.5429
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6412 and b: 2.5617
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6132 and b: 2.5576
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6484 and b: 2.5669
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6569 and b: 2.5686
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6883 and b: 2.5821
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7259 and b: 2.5937
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6406 and b: 2.5812
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6704 and b: 2.5982
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6988 and b: 2.6052
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7261 and b: 2.6158
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7274 and b: 2.6160
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6520 and b: 2.6052
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6650 and b: 2.6079
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6589 and b: 2.6066
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6280 and b: 2.6016
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6299 and b: 2.6020
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6465 and b: 2.6229
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5934 and b: 2.6151
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6202 and b: 2.6260
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5988 and b: 2.6217
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6258 and b: 2.6404
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5981 and b: 2.6364
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6332 and b: 2.6456
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6416 and b: 2.6473
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6729 and b: 2.6608
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7102 and b: 2.6723
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6254 and b: 2.6598
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6550 and b: 2.6767
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6832 and b: 2.6837
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7104 and b: 2.6942
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.7117 and b: 2.6944
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6367 and b: 2.6837
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6497 and b: 2.6864
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6435 and b: 2.6851
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6128 and b: 2.6801
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6147 and b: 2.6805
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6313 and b: 2.7013
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5785 and b: 2.6936
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6050 and b: 2.7043
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5837 and b: 2.7001
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6105 and b: 2.7187
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5832 and b: 2.7147
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6181 and b: 2.7239
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6265 and b: 2.7256
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6575 and b: 2.7389
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6947 and b: 2.7504
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6102 and b: 2.7379
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6396 and b: 2.7547
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6677 and b: 2.7618
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6947 and b: 2.7721
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6960 and b: 2.7724
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6215 and b: 2.7617
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6344 and b: 2.7644
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6282 and b: 2.7631
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5977 and b: 2.7581
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5997 and b: 2.7585
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6161 and b: 2.7792
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5636 and b: 2.7715
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5900 and b: 2.7822
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5687 and b: 2.7779
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5953 and b: 2.7964
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5683 and b: 2.7925
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6031 and b: 2.8016
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6115 and b: 2.8033
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6423 and b: 2.8166
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6793 and b: 2.8280
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.5952 and b: 2.8156
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6244 and b: 2.8323
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6524 and b: 2.8393
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6791 and b: 2.8496
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6805 and b: 2.8498
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6064 and b: 2.8392
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6192 and b: 2.8419
# 3.065
# Update: train accuracy: 3.0650 value of W: 3.6130 and b: 2.8406

# %%
line = np.linspace(0, 10, 100)
plt.plot(x, temp, 'o')
plt.plot(line, lr.predict(line));
# Out:
# ______________________
# [  1.40396396   1.79731735   2.19067074   2.58402413   2.97737752
#    3.37073091   3.7640843    4.15743769   4.55079108   4.94414446
#    5.33749785   5.73085124   6.12420463   6.51755802   6.91091141
#    7.3042648    7.69761819   8.09097158   8.48432497   8.87767836
#    9.27103175   9.66438513  10.05773852  10.45109191  10.8444453
#   11.23779869  11.63115208  12.02450547  12.41785886  12.81121225
#   13.20456564  13.59791903  13.99127242  14.3846258   14.77797919
#   15.17133258  15.56468597  15.95803936  16.35139275  16.74474614
#   17.13809953  17.53145292  17.92480631  18.3181597   18.71151309
#   19.10486647  19.49821986  19.89157325  20.28492664  20.67828003
#   21.07163342  21.46498681  21.8583402   22.25169359  22.64504698
#   23.03840037  23.43175375  23.82510714  24.21846053  24.61181392
#   25.00516731  25.3985207   25.79187409  26.18522748  26.57858087
#   26.97193426  27.36528765  27.75864104  28.15199442  28.54534781
#   28.9387012   29.33205459  29.72540798  30.11876137  30.51211476
#   30.90546815  31.29882154  31.69217493  32.08552832  32.47888171
#   32.87223509  33.26558848  33.65894187  34.05229526  34.44564865
#   34.83900204  35.23235543  35.62570882  36.01906221  36.4124156
#   36.80576899  37.19912238  37.59247576  37.98582915  38.37918254
#   38.77253593  39.16588932  39.55924271  39.9525961   40.34594949]
